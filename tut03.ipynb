# %% [markdown]
# <a href="https://colab.research.google.com/github/davideandres95/ml_comm/blob/main/tut03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Tutorial 3:
# November 4, 2021

# %%
import torch
from torch import nn, optim
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Problem 3.1 - Numeric stability
# Consider the code :

# %%
def f64(x):
    x = x.type(torch.float64)
    x = torch.exp(x)
    return torch.log(x)

def f16(x):
    x = x.type(torch.float16)
    return x

# %% [markdown]
# 1. What is the smallest integer value x for which f64(x)!=x?

# %%
for L_expected in torch.arange(0, 1000):
    L_actual = f64(L_expected)
    if L_expected != L_actual:
        break
print(f'expected: {L_expected}, f64({L_expected})={f64(L_expected)}')
# Out:
# expected: 710, f64(710)=inf

# %% [markdown]
# 2. For the value x determined in 1., do you have f16(x)=x?

# %%
print(f'f16({L_expected})={f16(L_expected)}')
# Out:
# f16(710)=710.0

# %% [markdown]
# 3. Repeat the analysis for 1. and 2. to compare a float64 implementation of the log-
# sum-exp expression on the left-hand side of (3.15) to a float16 implementation
# of the right-hand side of .
#
# $$ \log_2 \big( \sum_{j=0}^{M-1}  e^{\ell_j}\big) = \ell^*  \log_2(e) + \log_2 \big(\sum_{j=0}^{M-1} e^{\ell_j-\ell*}\big)$$
#
#  $$  \ell^* = \max \{ \ell_0,\dots, \ell_{M-1} \}$$

# %%
def left_hand_side_64(likelihoods):
    likelihoods = likelihoods.type(torch.float64)
    
    return(torch.log2(torch.sum(torch.exp(likelihoods))))

# %%
def rigth_hand_side_32(likelihoods):
    likelihoods = likelihoods.type(torch.float32)
    l_star = torch.max(likelihoods)
    diff = likelihoods - l_star
    return(l_star*torch.log2(torch.exp(torch.tensor(1.))) + torch.log2(torch.sum(torch.exp(diff))))

# %%
likelihoods = torch.tensor([1, 4, 13, 2])
print(f'Left hand side with float 64: {left_hand_side_64(likelihoods):.3f}')
print(f'Rigth hand side with float 32: {rigth_hand_side_32(likelihoods):.3f}')
# Out:
# Left hand side with float 64: 18.755
# Rigth hand side with float 32: 18.755

# %% [markdown]
# ### Problem 3.2 - How good is the simple AWGN NN Demapper?

# %%
def mapper(msg, alphabet=np.array([-3., -1., 1., 3.])):
    return alphabet[msg]

def awgn_channel(x, snr, seed=None):
    rng = np.random.Generator(np.random.PCG64(seed))
    power_x = np.mean(np.abs(X) ** 2)
    noise_power = power_x / snr
    noise = np.sqrt(noise_power) * rng.normal(size=x.shape) 
    return x + noise

# %% [markdown]
# 1. Calculate $P_{A|Y} (\cdot|y)$ in terms of channel output $y$, mapper function $\phi$, and noise
# variance $\sigma^2_z$.
#
# $$ P_{A|Y}(a|y) = \frac{P_A(a) P_{Y|A}(a|y)}{P_Y(y)} = \frac{P_A(a) P_{Y|A}(a|y)}{\sum_{j=0}^{M-1} P_{A(j)} P_{Y|A}(y|j)} $$ with $$P_{Y|A}(a|y) = \frac{1}{\sqrt{2 \pi \sigma_z ^2}} e ^{-\frac{1}{2 \sigma^2}(y-a)^2}$$

# %% [markdown]
# 2. Suppose A is uniformly distributed. The signal-to-noise ratio (SNR) in dB is
# $$\text{SNRdB} = 10 \log\frac{E(X^2)}{E(Z^2)}.$$
# For SNRdB = {5, 6, 7, ... , 10}, use sample sequences to calculate an equivocation estimate $\hat{H}(M|Y)$ and plot the mutual information estimate:
# $$I(A; Y ) = H(A) - \hat{H}(A|Y ) $$ [bits]

# %%
M = 4 # cardinality of the alphabet
chi = [-3., -1., 1., 3.] # alphabet
a = np.random.choice(M,10000) # messages
X = mapper(a) # symbols

def calculate_py_given_x(x, y, sigma2):
    return (1/(np.sqrt(2*np.pi*sigma2))) * np.exp(-(y-x)**2/sigma2/2) 


def calculate_px_given_y(x, y, sigma2, chi):
    py = 0
    for i in chi:
        py += 0.25 * calculate_py_given_x(i, y, sigma2)  
    pxy = 0.25 * calculate_py_given_x(x, y, sigma2) / py
    return pxy


SNRdBs = np.array([5,6,7,8,9,10])
mi = np.zeros(SNRdBs.size)
SNRs = 10**(SNRdBs/10)
for idx,snr in enumerate(SNRs):
    Y = awgn_channel(X, snr)
    pxy = calculate_px_given_y(X, Y, np.mean(np.abs(X) ** 2)/snr, chi)
    mi[idx] = np.log2(M)-(-np.mean(np.log2(pxy)))

plt.plot(SNRdBs, mi, label='MI (analytical)')
plt.plot(SNRdBs, 0.5 * np.log2(1+ SNRs), label='AWGN Capacity') 
plt.xlabel('SNR [dB]')
plt.ylabel('Mutual Information')
plt.legend()
plt.grid()

# %% [markdown]
# 3. For each SNR value from 2., train an AWGN NN demapper as in Figure 3.6 using
# the cross equivocation cost for log probabilities (3.18).

# %%
class awgn_demapper(nn.Module):
    def __init__(self):
        super().__init__()
        self.out = nn.Linear(1, 4)

    def forward(self, y):
        y = self.out(y)
        return y

# %%
# Prepare data
a_t = torch.Tensor(a.reshape(-1,))
a_t = a_t.type(torch.LongTensor)
# Loss function
loss_fn = nn.CrossEntropyLoss()

# %%
def calculate_prob(logit, a_t): 
    l = logit.detach().numpy()
    a = a_t.detach().numpy()
    la = l[range(len(a)), a]
    return np.exp(la) / np.sum(np.exp(l), 1)

# Trainings loop
probs = np.zeros((SNRs.size, 10000))
equivocations = np.zeros(SNRs.size)
for idx,snr in enumerate(SNRs):
    print(f'---- SNR is: {snr:.2f}')
    # Initialize network
    demap = awgn_demapper()
    # Optimizer
    optimizer = optim.Adam(demap.parameters(), lr=0.05)
    Y = awgn_channel(X, snr)
    y = torch.Tensor(Y.reshape(-1, 1))
    for j in range(1000):
        logit = demap(y).reshape(-1, 4)
        loss = loss_fn(logit, a_t)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Printout and visualization
        if j % 50 == 0:
            print(f'epoch {j}: Loss = {loss.detach().numpy() :.4f}')
    probs[idx, :]=calculate_prob(logit, a_t)
    equivocations[idx] = loss / np.log(2)
# Out:
# ---- SNR is: 3.16
# epoch 0: Loss = 2.2846
# epoch 50: Loss = 0.7333
# epoch 100: Loss = 0.7089
# epoch 150: Loss = 0.7048
# epoch 200: Loss = 0.7039
# epoch 250: Loss = 0.7037
# epoch 300: Loss = 0.7036
# epoch 350: Loss = 0.7036
# epoch 400: Loss = 0.7036
# epoch 450: Loss = 0.7036
# epoch 800: Loss = 0.3809
# epoch 850: Loss = 0.3808
# epoch 900: Loss = 0.3807
# epoch 950: Loss = 0.3807
# ---- SNR is: 10.00
# epoch 0: Loss = 2.4894
# epoch 50: Loss = 0.5542
# epoch 100: Loss = 0.4268
# epoch 150: Loss = 0.3738
# epoch 200: Loss = 0.3445
# epoch 250: Loss = 0.3266
# epoch 300: Loss = 0.3152
# epoch 350: Loss = 0.3075
# epoch 400: Loss = 0.3023
# epoch 450: Loss = 0.2987
# epoch 500: Loss = 0.2961
# epoch 550: Loss = 0.2942
# epoch 600: Loss = 0.2929
# epoch 650: Loss = 0.2920
# epoch 700: Loss = 0.2913
# epoch 750: Loss = 0.2908
# epoch 800: Loss = 0.2904
# epoch 850: Loss = 0.2901
# epoch 900: Loss = 0.2899
# epoch 950: Loss = 0.2898

# %% [markdown]
# 4. For the trained NN demappers, calculate equivocation estimates from input and
# output sequences. Plot the corresponding mutual information estimate. What is
# the gap in mutual information and in SNR, compared to the analytical demapper
# from 2.?

# %%
mi_nn = np.log2(4)-(-np.mean(np.log2(probs), axis=1))
mi_nn_from_loss = np.log2(4) - equivocations
plt.plot(SNRdBs, mi_nn, label='MI (Neural Network, from output)')
plt.plot(SNRdBs, mi_nn_from_loss, label='MI (Neural Network, from loss)', linestyle='dashed')
plt.plot(SNRdBs, mi, label='MI (analytical)')
plt.plot(SNRdBs, 0.5 * np.log2(1+ SNRs), label='AWGN Capacity')
plt.legend()
plt.grid()

# %% [markdown]
# 6. For $\text{SNRdB} = 5$ and $-4 \leq  y  \leq 4$, plot the distributions $P_{A|Y} (i|y)$ as function of
# $y$ for $i = 0, 1, 2, 3$. For the same values of $y$, also plot the probabilities calculated
# from the log probabilities output by the NN demapper trained for $\text{SNRdB} = 5$.
# How well does the NN demapper approximate the analytical probabilities?

# %%
# Train the network at 5 dB
SNRdB = 5
snr =  10**(SNRdB/10)
Y = awgn_channel(X, snr)
# Initialize network
demap = awgn_demapper()
# Optimizer
optimizer = optim.Adam(demap.parameters(), lr=0.05)
a_t = torch.Tensor(a.reshape(-1,))
a_t = a_t.type(torch.LongTensor)
y = torch.Tensor(Y.reshape(-1, 1))
for j in range(1000):
    logit = demap(y).reshape(-1, 4)
    loss = loss_fn(logit, a_t)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    # Printout and visualization
    if j % 50 == 0:
        print(f'epoch {j}: Loss = {loss.detach().numpy() :.4f}')

probs = calculate_prob(logit, a_t)
# Out:
# epoch 0: Loss = 1.6817
# epoch 50: Loss = 0.7324
# epoch 100: Loss = 0.7038
# epoch 150: Loss = 0.6998
# epoch 200: Loss = 0.6992
# epoch 250: Loss = 0.6992
# epoch 300: Loss = 0.6992
# epoch 350: Loss = 0.6992
# epoch 400: Loss = 0.6992
# epoch 450: Loss = 0.6992
# epoch 500: Loss = 0.6992
# epoch 550: Loss = 0.6992
# epoch 600: Loss = 0.6992
# epoch 650: Loss = 0.6992
# epoch 700: Loss = 0.6992
# epoch 750: Loss = 0.6992
# epoch 800: Loss = 0.6992
# epoch 850: Loss = 0.6992
# epoch 900: Loss = 0.6992
# epoch 950: Loss = 0.6992

# %%
# Analytical:
sigma2 = np.mean(np.abs(X) ** 2)/snr
y = np.arange(-6, 6+0.1, 0.1)
for i in range(M):
    pay = calculate_px_given_y(chi[i], y, sigma2, chi)
    plt.plot(y, pay, label="i="+str(i))
# NN:
logit = demap(torch.Tensor(y).reshape(-1, 1)).reshape(-1, 4).detach().numpy()
pay_nn = np.exp(logit) / np.sum(np.exp(logit), 1).reshape(-1, 1)
for i in range(M):
    plt.plot(y, pay_nn[:, i].reshape(-1), label=f'i={i} (NN)', linestyle='dashed')

plt.grid()
plt.legend()
plt.xlabel('y')
plt.ylabel('$P_{M|Y} (i|y)$')
plt.show()

# %% [markdown]
# ### Problem 3.3 - Log probabilities versus probabilities

# %% [markdown]
# 1. Repeat steps 3.-4. and 6. of Problem 3.2 for the demapper in Figure 3.6 terminated as
# in Figure 3.3, using the cross equivocation cost (3.7).
# Do you observe differences to the results from Problem 3.2?

# %%
class awgn_demapper2(nn.Module):
    def __init__(self):
        super().__init__()
        self.h1 = nn.Linear(1, 4)
        self.out = nn.Sigmoid()

    def forward(self, y):
        y = self.out(self.h1(y))
        return y/torch.sum(y, 1).reshape(-1, 1)

# %%
# Prepare data
y = torch.Tensor(Y.reshape(-1, 1))
a_t = torch.Tensor(a.reshape(-1,))
a_t = a_t.type(torch.LongTensor)

# Define loss function and optimizer
loss_fn = nn.NLLLoss()

equivocations = np.zeros(SNRs.size)
probs=np.zeros((SNRs.size,10000))
for idx,snr in enumerate(SNRs):
    print(f'--- SNR is: {snr:.2f}---')
    # Initialize network
    demap2 = awgn_demapper2()
    # Optimizer
    optimizer = optim.Adam(demap2.parameters(), lr=0.005)
    Y = awgn_channel(X, snr)
    y = torch.Tensor(Y.reshape(-1, 1))
    for j in range(10000):
        prob = demap2(y).reshape(-1, 4)
        loss = loss_fn(torch.log(prob), a_t)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Printout and visualization
        if j % 50 == 0:
            print(f'epoch {j}: Loss = {loss.detach().numpy() :.4f}')
    probs[idx,:] = prob.detach().numpy()[range(len(a)), a]
    equivocations[idx] = loss / np.log(2)
# Out:
# --- SNR is: 3.16---
# epoch 0: Loss = 1.2938
# epoch 50: Loss = 1.1287
# epoch 100: Loss = 1.0252
# epoch 150: Loss = 0.9658
# epoch 200: Loss = 0.9293
# epoch 250: Loss = 0.9050
# epoch 300: Loss = 0.8880
# epoch 350: Loss = 0.8757
# epoch 400: Loss = 0.8664
# epoch 450: Loss = 0.8592
# epoch 500: Loss = 0.8536
# epoch 550: Loss = 0.8491
# epoch 600: Loss = 0.8454
# epoch 650: Loss = 0.8425
# epoch 700: Loss = 0.8400
# epoch 750: Loss = 0.8379
# epoch 800: Loss = 0.8362
# epoch 850: Loss = 0.8347
# epoch 900: Loss = 0.8335
# epoch 950: Loss = 0.8324
# epoch 1000: Loss = 0.8314
# epoch 1050: Loss = 0.8306
# epoch 1100: Loss = 0.8299
# epoch 1150: Loss = 0.8293
# epoch 6200: Loss = 0.4380
# epoch 6250: Loss = 0.4355
# epoch 6300: Loss = 0.4335
# epoch 6350: Loss = 0.4318
# epoch 6400: Loss = 0.4303
# epoch 6450: Loss = 0.4291
# epoch 6500: Loss = 0.4280
# epoch 6550: Loss = 0.4271
# epoch 6600: Loss = 0.4263
# epoch 6650: Loss = 0.4256
# epoch 6700: Loss = 0.4250
# epoch 6750: Loss = 0.4245
# epoch 6800: Loss = 0.4240
# epoch 6850: Loss = 0.4236
# epoch 6900: Loss = 0.4232
# epoch 6950: Loss = 0.4229
# epoch 7000: Loss = 0.4225
# epoch 7050: Loss = 0.4223
# epoch 7100: Loss = 0.4220
# epoch 7150: Loss = 0.4217
# epoch 7200: Loss = 0.4215
# epoch 7250: Loss = 0.4213
# epoch 7300: Loss = 0.4211
# epoch 7350: Loss = 0.4209
# epoch 7400: Loss = 0.4208
# epoch 7450: Loss = 0.4206
# epoch 7500: Loss = 0.4204
# epoch 7550: Loss = 0.4203
# epoch 7600: Loss = 0.4202
# epoch 7650: Loss = 0.4200
# epoch 7700: Loss = 0.4199
# epoch 7750: Loss = 0.4198
# epoch 7800: Loss = 0.4197
# epoch 7850: Loss = 0.4196
# epoch 7900: Loss = 0.4195
# epoch 7950: Loss = 0.4194
# epoch 8000: Loss = 0.4193
# epoch 8050: Loss = 0.4192
# epoch 8100: Loss = 0.4191
# epoch 8150: Loss = 0.4189
# epoch 8200: Loss = 0.4188
# epoch 8250: Loss = 0.4187
# epoch 8300: Loss = 0.4184
# epoch 8350: Loss = 0.4180
# epoch 8400: Loss = 0.4163
# epoch 8450: Loss = 0.3747
# epoch 8500: Loss = 0.3212
# epoch 8550: Loss = 0.3170
# epoch 8600: Loss = 0.3139
# epoch 8650: Loss = 0.3116
# epoch 8700: Loss = 0.3096
# epoch 8750: Loss = 0.3080
# epoch 8800: Loss = 0.3066
# epoch 8850: Loss = 0.3054
# epoch 8900: Loss = 0.3043
# epoch 8950: Loss = 0.3034
# epoch 9000: Loss = 0.3025
# epoch 9050: Loss = 0.3018
# epoch 9100: Loss = 0.3011
# epoch 9150: Loss = 0.3005
# epoch 9200: Loss = 0.2999
# epoch 9250: Loss = 0.2994
# epoch 9300: Loss = 0.2989
# epoch 9350: Loss = 0.2985
# epoch 9400: Loss = 0.2981
# epoch 9450: Loss = 0.2977
# epoch 9500: Loss = 0.2973
# epoch 9550: Loss = 0.2970
# epoch 9600: Loss = 0.2967
# epoch 9650: Loss = 0.2965
# epoch 9700: Loss = 0.2962
# epoch 9750: Loss = 0.2960
# epoch 9800: Loss = 0.2958
# epoch 9850: Loss = 0.2956
# epoch 9900: Loss = 0.2954
# epoch 9950: Loss = 0.2952

# %%
mi_nn_2 = np.log2(4)-(-np.mean(np.log2(probs), axis=1))
mi_nn_2_loss = np.log2(4)-equivocations
plt.plot(SNRdBs, mi_nn_2, label='MI (Neural Network 2)')
plt.plot(SNRdBs, mi_nn_2_loss, linestyle='dashed', label='MI (Neural Network 2)')
plt.plot(SNRdBs, mi, label='MI (analytical)')
plt.plot(SNRdBs, 0.5 * np.log2(1+ SNRs), label='AWGN Capacity')
plt.legend()
plt.grid()
plt.show()
# TODO: problems for large SNR ==> this should be due to numerical issues

# %% [markdown]
# 2. Repeat steps 3.-5. of Problem 3.2 for the demapper in Figure 3.6 terminated as in Figure 3.4, using the cross equivocation cost (3.7).
# Do you observe differences to the results from Problem 3.2?

# %%
class awgn_demapper3(nn.Module):
    def __init__(self):
        super().__init__()
        self.h1 = nn.Linear(1, 4)
        self.out = nn.Softmax(dim=1)

    def forward(self, y):
        y = self.out(self.h1(y))
        return y

# %%
# Prepare data
y = torch.Tensor(Y.reshape(-1, 1))
a_t = torch.Tensor(a.reshape(-1,))
a_t = a_t.type(torch.LongTensor)

# Define loss function and optimizer
loss_fn = nn.NLLLoss()

# %%
# Trainings loop
probs=np.zeros((SNRs.size,10000))
for idx,snr in enumerate(SNRs):
    print(f'--- SNR is: {snr:.2f}---')
    # Initialize network
    demap3 = awgn_demapper3()
    # Optimizer
    optimizer = optim.Adam(demap3.parameters(), lr=0.05)
    Y = awgn_channel(X, snr)
    y = torch.Tensor(Y.reshape(-1, 1))
    for j in range(1000):
        prob = demap3(y).reshape(-1, 4)
        loss = loss_fn(torch.log(prob), a_t)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Printout and visualization
        if j % 50 == 0:
            print(f'epoch {j}: Loss = {loss.detach().numpy() :.4f}')
    probs[idx,:] = prob.detach().numpy()[range(len(a)), a]
# Out:
# --- SNR is: 3.16---
# epoch 0: Loss = 2.4939
# epoch 50: Loss = 0.7514
# epoch 100: Loss = 0.7128
# epoch 150: Loss = 0.7054
# epoch 200: Loss = 0.7035
# epoch 250: Loss = 0.7031
# epoch 300: Loss = 0.7030
# epoch 350: Loss = 0.7030
# epoch 400: Loss = 0.7030
# epoch 450: Loss = 0.7030
# epoch 500: Loss = 0.7030
# epoch 550: Loss = 0.7030
# epoch 600: Loss = 0.7030
# epoch 650: Loss = 0.7030
# epoch 700: Loss = 0.7030
# epoch 750: Loss = 0.7030
# epoch 800: Loss = 0.7030
# epoch 850: Loss = 0.7030
# epoch 900: Loss = 0.7030
# epoch 950: Loss = 0.7030
# --- SNR is: 3.98---
# epoch 0: Loss = 1.8696
# epoch 50: Loss = 0.6936
# epoch 100: Loss = 0.6480
# epoch 150: Loss = 0.6358
# epoch 200: Loss = 0.6319
# epoch 250: Loss = 0.6308
# epoch 300: Loss = 0.6304
# epoch 350: Loss = 0.6303
# epoch 400: Loss = 0.6303
# epoch 450: Loss = 0.6303
# epoch 500: Loss = 0.6303
# epoch 550: Loss = 0.6303
# epoch 600: Loss = 0.6303
# epoch 650: Loss = 0.6303
# epoch 700: Loss = 0.6303
# epoch 750: Loss = 0.6303
# epoch 800: Loss = 0.6303
# epoch 850: Loss = 0.6303
# epoch 900: Loss = 0.6303
# epoch 950: Loss = 0.6303
# --- SNR is: 5.01---
# epoch 0: Loss = 1.5584
# epoch 50: Loss = 0.5898
# epoch 100: Loss = 0.5529
# epoch 150: Loss = 0.5438
# epoch 200: Loss = 0.5413
# epoch 250: Loss = 0.5406
# epoch 300: Loss = 0.5404
# epoch 350: Loss = 0.5403
# epoch 400: Loss = 0.5403
# epoch 450: Loss = 0.5403
# epoch 500: Loss = 0.5403
# epoch 550: Loss = 0.5403
# epoch 600: Loss = 0.5403
# epoch 650: Loss = 0.5403
# epoch 700: Loss = 0.5403
# epoch 750: Loss = 0.5403
# epoch 800: Loss = 0.5403
# epoch 850: Loss = 0.5403
# epoch 900: Loss = 0.5403
# epoch 950: Loss = 0.5403
# --- SNR is: 6.31---
# epoch 0: Loss = 2.0823
# epoch 50: Loss = 0.6222
# epoch 100: Loss = 0.5256
# epoch 150: Loss = 0.4898
# epoch 200: Loss = 0.4728
# epoch 250: Loss = 0.4639
# epoch 300: Loss = 0.4592
# epoch 350: Loss = 0.4567
# epoch 400: Loss = 0.4553
# epoch 450: Loss = 0.4546
# epoch 500: Loss = 0.4542
# epoch 550: Loss = 0.4540
# epoch 600: Loss = 0.4539
# epoch 650: Loss = 0.4538
# epoch 700: Loss = 0.4538
# epoch 750: Loss = 0.4538
# epoch 800: Loss = 0.4538
# epoch 850: Loss = 0.4538
# epoch 900: Loss = 0.4538
# epoch 950: Loss = 0.4538
# --- SNR is: 7.94---
# epoch 0: Loss = 1.7490
# epoch 50: Loss = 0.5797
# epoch 100: Loss = 0.4803
# epoch 150: Loss = 0.4370
# epoch 200: Loss = 0.4137
# epoch 250: Loss = 0.4002
# epoch 300: Loss = 0.3920
# epoch 350: Loss = 0.3869
# epoch 400: Loss = 0.3837
# epoch 450: Loss = 0.3816
# epoch 500: Loss = 0.3803
# epoch 550: Loss = 0.3795
# epoch 600: Loss = 0.3789
# epoch 650: Loss = 0.3786
# epoch 700: Loss = 0.3784
# epoch 750: Loss = 0.3783
# epoch 800: Loss = 0.3782
# epoch 850: Loss = 0.3782
# epoch 900: Loss = 0.3781
# epoch 950: Loss = 0.3781
# --- SNR is: 10.00---
# epoch 0: Loss = 2.5744
# epoch 50: Loss = 0.6223
# epoch 100: Loss = 0.4902
# epoch 150: Loss = 0.4249
# epoch 200: Loss = 0.3849
# epoch 250: Loss = 0.3585
# epoch 300: Loss = 0.3401
# epoch 350: Loss = 0.3270
# epoch 400: Loss = 0.3173
# epoch 450: Loss = 0.3101
# epoch 500: Loss = 0.3046
# epoch 550: Loss = 0.3004
# epoch 600: Loss = 0.2971
# epoch 650: Loss = 0.2945
# epoch 700: Loss = 0.2925
# epoch 750: Loss = 0.2910
# epoch 800: Loss = 0.2897
# epoch 850: Loss = 0.2887
# epoch 900: Loss = 0.2879
# epoch 950: Loss = 0.2873

# %%
mi_nn_3 = np.log2(4)-(-np.mean(np.log2(probs), axis=1))
plt.plot(SNRdBs, mi_nn_3, label='MI (Neural Network 3)')
plt.plot(SNRdBs, mi, label='MI (analytical)')
plt.plot(SNRdBs, 0.5 * np.log2(1+ SNRs), label='AWGN Capacity')
plt.legend()
plt.grid()
